# %%
a = 'a'
a

# %%
sns.box

# %%
sns.boxplot(data= notas, x = "FilmeId", y ='No')

# %% [markdown]
# # Analisando notas em geral

# %%
import pandas as pd

# %%
notas = pd.read_csv("Dados/ratings.csv")
notas.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns =[ "UsuarioId","FilmeId","Nota","Momento"]

# %%
notas
# Out:
#         UsuarioId  FilmeId  Nota     Momento
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas['Nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: Nota, Length: 100836, dtype: float64

# %%
notas['Nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['Nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: Nota, dtype: int64

# %%
notas['Nota'].mean()
# Out:
# 3.501556983616962

# %%
notas.Nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: Nota, Length: 100836, dtype: float64

# %%
notas.Nota.head(5)
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: Nota, dtype: float64

# %%
notas.Nota.plot()
# Out:
# <AxesSubplot:>

# %%
notas.Nota.plot(kind='hist') # kind é para colocar o tipo de grafico
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(f"Media { notas['Nota'].mean()} ") # media
print(f'Mediana {notas.Nota.median()}') # mediana
# Out:
# Media 3.501556983616962
# Mediana 3.5

# %%
notas.Nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: Nota, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(notas.Nota)
# Out:
# <AxesSubplot:xlabel='Nota'>

# %% [markdown]
# # Olhando Os Filmes

# %%
filmes = pd.read_csv("Dados/movies.csv")

# %%
filmes.columns = ['FilmeId','Titulo','Genero']

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    UsuarioId  FilmeId  Nota    Momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# # Analisando Algumas notas específicas por filme

# %%
notas.query("FilmeId == 1").Nota
# Out:
# 0        4.0
# 516      4.0
# 874      4.5
# 1434     2.5
# 1667     4.5
#         ...
# 97364    2.5
# 98479    4.0
# 98666    2.5
# 99497    3.0
# 99534    5.0
# Name: Nota, Length: 215, dtype: float64

# %%
notas.query('FilmeId == 1').Nota.mean()
# Out:
# 3.9209302325581397

# %%
notas.query('FilmeId == 2 ').Nota.mean()
# Out:
# 3.4318181818181817

# %%
notas.groupby("FilmeId").mean()
# Out:
#           UsuarioId      Nota       Momento
# FilmeId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
medias_por_filmes = notas.groupby('FilmeId').mean()['Nota'] # Apenas a coluna nota
medias_por_filmes.head()
# Out:
# FilmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: Nota, dtype: float64

# %%
medias_por_filmes.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filmes)
# Out:
# <AxesSubplot:xlabel='Nota'>

# %%
sns.distplot(medias_por_filmes) #bins é o total de "caixinhas"
# Out:
# <AxesSubplot:xlabel='Nota', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(medias_por_filmes, bins=25)
plt.title('Histograma das Medias dos filmes')
# Out:
# Text(0.5, 1.0, 'Histograma das Medias dos filmes')

# %%
tmdb = pd.read_csv("Dados/tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.original_language
# Out:
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en
#         ..
# 4798    es
# 4799    en
# 4800    en
# 4801    en
# 4802    en
# Name: original_language, Length: 4803, dtype: object

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# cs       2
# ar       2
# ro       2
# id       2
# ta       2
# te       1
# hu       1
# nb       1
# xx       1
# ps       1
# vi       1
# is       1
# ky       1
# no       1
# af       1
# tr       1
# pl       1
# sl       1
# el       1
# Name: original_language, dtype: int64

# %%
tmdb.original_language.value_counts().to_frame() # transformando a Series em um dataFrame
# Out:
#     original_language
# en               4505
# fr                 70
# es                 32
# de                 27
# zh                 27
# hi                 19
# ja                 16
# it                 14
# cn                 12
# ko                 11
# ru                 11
# pt                  9
# da                  7
# sv                  5
# nl                  4
# fa                  4
# th                  3
# he                  3
# cs                  2
# ar                  2
# ro                  2
# id                  2
# ta                  2
# te                  1
# hu                  1
# nb                  1
# xx                  1
# ps                  1
# vi                  1
# is                  1
# ky                  1
# no                  1
# af                  1
# tr                  1
# pl                  1
# sl                  1
# el                  1

# %%
tmdb.original_language.value_counts().to_frame().reset_index()
# Out:
#    index  original_language
# 0     en               4505
# 1     fr                 70
# 2     es                 32
# 3     de                 27
# 4     zh                 27
# 5     hi                 19
# 6     ja                 16
# 7     it                 14
# 8     cn                 12
# 9     ko                 11
# 10    ru                 11
# 11    pt                  9
# 12    da                  7
# 13    sv                  5
# 14    nl                  4
# 15    fa                  4
# 16    th                  3
# 17    he                  3
# 18    cs                  2
# 19    ar                  2
# 20    ro                  2
# 21    id                  2
# 22    ta                  2
# 23    te                  1
# 24    hu                  1
# 25    nb                  1
# 26    xx                  1
# 27    ps                  1
# 28    vi                  1
# 29    is                  1
# 30    ky                  1
# 31    no                  1
# ...

# %%
contagem_de_lingua = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ['original_language','Total']
contagem_de_lingua.head()
# Out:
#   original_language  Total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                de     27
# 4                zh     27

# %%
sns.barplot(x='original_language', y = 'Total', data = contagem_de_lingua)
# Out:
# <AxesSubplot:xlabel='original_language', ylabel='Total'>

# %%
sns.catplot(x='original_language', kind='count',data=tmdb) # Mesma coiso de de cima porem de forma mais bruta

# %%
plt.pie(contagem_de_lingua['Total'],labels=contagem_de_lingua['original_language']) # Geralmenta não é utilizado por nao ter uma boa vizualização
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc834554040>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'de'),
#   Text(1.0773191105706255, -0.22222406260195313, 'zh'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ko'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ru'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua = tmdb.original_language.value_counts()
total_por_lingua
# Out:
# en    4505
# fr      70
# es      32
# de      27
# zh      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# cs       2
# ar       2
# ro       2
# id       2
# ta       2
# te       1
# hu       1
# nb       1
# xx       1
# ps       1
# vi       1
# is       1
# ky       1
# no       1
# af       1
# tr       1
# pl       1
# sl       1
# el       1
# Name: original_language, dtype: int64

# %%
total_geral = total_por_lingua.sum()
total_em_ingles = total_por_lingua.loc['en']
total_resto = total_geral - total_em_ingles
print(total_geral, total_resto)
# Out:
# 4803 298

# %%
dados ={
    'lingua':['ingles','outros'],
    'total':[total_em_ingles,total_resto]
}
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data=dados, x='lingua', y ='total')
# Out:
# <AxesSubplot:xlabel='lingua', ylabel='total'>

# %%
tmdb.query("original_language != 'en'")
# Out:
#         budget                                             genres  \
# 97    15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 235   97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317   94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474          0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 492    8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
# ...        ...                                                ...
# 4739         0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4751         0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4790         0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 4792     20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4798    220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                                homepage      id  \
# 97                                                  NaN  315011
# ...

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()
total_por_lingua_de_outros_filmes
# Out:
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# nl     4
# fa     4
# he     3
# th     3
# ta     2
# ar     2
# ro     2
# id     2
# cs     2
# te     1
# xx     1
# vi     1
# el     1
# af     1
# nb     1
# pl     1
# sl     1
# tr     1
# hu     1
# ky     1
# ps     1
# is     1
# no     1
# Name: original_language, dtype: int64

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en' ")

# %%
total_por_lingua_de_outros_filmes.index
# Out:
# Index(['fr', 'es', 'zh', 'de', 'hi', 'ja', 'it', 'cn', 'ko', 'ru', 'pt', 'da',
#        'sv', 'nl', 'fa', 'he', 'th', 'ta', 'ar', 'ro', 'id', 'cs', 'te', 'xx',
#        'vi', 'el', 'af', 'nb', 'pl', 'sl', 'tr', 'hu', 'ky', 'ps', 'is', 'no'],
#       dtype='object')

# %%
sns.catplot(x = 'original_language', kind='count', data= filmes_sem_lingua_original_em_ingles,aspect=2, order= total_por_lingua_de_outros_filmes.index,palette='GnBu_d') # aspect muda a largura order = ordena com uma lista palette = Cor

# %% [markdown]
# # Grafico linear

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# # Revisando o papel da média, mediana, medidas de tendência central, dispersão,desvio padrão, box plot,histograma

# %%
 filmes.head()
# Out:
#    FilmeId                              Titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         Genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.head(2)
# Out:
#    FilmeId            Titulo                                       Genero
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_toy_story = notas.query('FilmeId == 1')
len(notas_toy_story)
# Out:
# 215

# %%
notas_jumanji = notas.query('FilmeId == 2')
len(notas_jumanji)
# Out:
# 110

# %%
print(f'Nota media do toy story { notas_toy_story.Nota.mean() :.2f}')
print(f'Nota media do jumanji { notas_jumanji.Nota.mean() :.2f}')
# Out:
# Nota media do toy story 3.92
# Nota media do jumanji 3.43

# %%
import numpy as np
filme1 = np.append(np.array([2.5] * 10), np.array([3.5] * 10))
filme2 = np.append(np.array([5] * 10), np.array([1] * 10))
print(filme1.mean(), filme2.mean())
print(np.median(filme1),np.median(filme2))
print(np.std(filme1),np.std(filme2))
# Out:
# 3.0 3.0
# 3.0 3.0
# 0.5 2.0

# %%
sns.distplot(filme1)
sns.distplot(filme2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(filme1)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(filme2)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot([filme1,filme2]) # matplotlib tem como passar uma lista
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f19d7bcd340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f19dc242fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f19dc7c22b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f19d7d62850>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f19d7d62fd0>,
# ...
#  'means': []}

# %%
sns.boxplot(notas_toy_story.Nota)
sns.boxplot(notas_jumanji.Nota)
# Out:
# <AxesSubplot:xlabel='Nota'>

# %%
plt.boxplot([notas_toy_story.Nota, notas_jumanji.Nota])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f19d7a2d700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f19e3d08b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f19e3e77bb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f19dc817820>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f19d7d32af0>,
# ...
#  'means': []}

# %%
sns.boxplot(x = 'FilmeId', y='Nota', data= notas.query('FilmeId in [1,2,3,4,5]')) # Fazendo um range de quantos filmes eu quero
# Out:
# <AxesSubplot:xlabel='FilmeId', ylabel='Nota'>

# %%
print(notas_toy_story.Nota.std(),
notas_jumanji.Nota.std()) # Desvio padrao do pandas
# Out:
# 0.8348591407114045 0.8817134921476455
